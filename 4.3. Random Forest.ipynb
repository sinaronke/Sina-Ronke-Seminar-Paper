# %%
#Random Forest
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, f1_score

# %%
# Define all relevant features within an array
feature_selection = [
    "Switch ID", 
    "Port Number", 
    "Received Packets", 
    "Received Bytes", 
    "Sent Bytes", 
    "Sent Packets", 
    "Port alive Duration (S)", 
    "Delta Received Packets", 
    "Delta Received Bytes", 
    "Delta Sent Bytes", 
    "Delta Sent Packets", 
    "Delta Port alive Duration (S)", 
    "Connection Point", 
    "Total Load/Rate", 
    "Total Load/Latest", 
    "Unknown Load/Rate", 
    "Unknown Load/Latest", 
    "Latest bytes counter", 
    "Active Flow Entries", 
    "Packets Looked Up", 
    "Packets Matched"
]

# %%
#Import Cleaned UNR IDD Dataset with Network traffic
#Information about Data
#Label/Attacks are labeled with numbers: Blackhole = 1, Diversion: 2, "Normal": 3,"Overflow": 4, "PortScan": 5, "TCP-SYN": 6
#Binary Label is labeled: 1 = Attack, 2 = Normal
df = pd.read_csv("/Users/sinaronke/Predict Binary Label (Attack or Normal)/UNR_IDD_cleaned.csv")
df.head()
# Out:
#    Switch ID  Port Number  Received Packets  Received Bytes  Sent Bytes  \
# 0         12            1               132            9181     6311853
# 1         12            2               187         6304498       15713
# 2         12            3               235         6311567        8030
# 3         12            4                59            7878       16439
# 4         10            1               188         6304547       16497
#
#    Sent Packets  Port alive Duration (S)  Delta Received Packets  \
# 0           238                       46                       0
# 1           171                       46                     146
# 2            58                       46                       2
# 3           182                       46                       2
# 4           183                       46                       0
#
#    Delta Received Bytes  Delta Sent Bytes  ...  Total Load/Rate  \
# 0                     0               280  ...                0
# 1               5908166              5969  ...                0
# 2                   278               280  ...                0
# 3                   278               280  ...                0
# 4                     0               280  ...                0
#
#    Total Load/Latest  Unknown Load/Rate  Unknown Load/Latest  \
# 0                  0                  0                    0
# 1                  0                  0                    0
# 2                  0                  0                    0
# 3                  0                  0                    0
# 4                  0                  0                    0
#
#    Latest bytes counter  Active Flow Entries  Packets Looked Up  \
# 0                     0                    9                767
# 1                     0                    9                767
# 2                     0                    9                767
# 3                     0                    9                767
# 4                     0                    7                489
#
#    Packets Matched  Label  Binary Label
# 0              688      6             1
# 1              688      6             1
# 2              688      6             1
# 3              688      6             1
# 4              403      6             1
#
# [5 rows x 23 columns]

# %%
#pending variable y with Label (only 1 pending variable possible)
#delete "Label" is necessary to predict Label as y target
df = df.drop("Binary Label", axis=1)

# %%
#Blackhole = 1, Diversion: 2, "Normal": 3,"Overflow": 4, "PortScan": 5, "TCP-SYN": 6
df["Label"].value_counts(dropna=False)
# Out:
# 5    9498
# 6    8952
# 1    8397
# 2    5599
# 3    3723
# 4    1007
# Name: Label, dtype: int64

# %%
#Define X for features to train the model and define y as target for predicition
X = df[feature_selection]
y = df["Label"]

# %%
#Split the data in training and test. Random state = 42 necessary for Comparability. Test Size 70%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=None, random_state=42)

print('X_train:', X_train.shape, ' y_train:', y_train.shape)
print('X_test:', X_test.shape, ' y_test:', y_test.shape)
# Out:
# X_train: (27882, 21)  y_train: (27882,)
# X_test: (9294, 21)  y_test: (9294,)

# %%
#Check if dataframe splitting is random for test and training data
df.groupby(y_train).count()
df.groupby(y_test).count()
# Out:
#        Switch ID  Port Number  Received Packets  Received Bytes  Sent Bytes  \
# Label
# 1.0         2053         2053              2053            2053        2053
# 2.0         1388         1388              1388            1388        1388
# 3.0          947          947               947             947         947
# 4.0          226          226               226             226         226
# 5.0         2389         2389              2389            2389        2389
# 6.0         2291         2291              2291            2291        2291
#
#        Sent Packets  Port alive Duration (S)  Delta Received Packets  \
# Label
# 1.0            2053                     2053                    2053
# 2.0            1388                     1388                    1388
# 3.0             947                      947                     947
# 4.0             226                      226                     226
# 5.0            2389                     2389                    2389
# 6.0            2291                     2291                    2291
#
#        Delta Received Bytes  Delta Sent Bytes  ...  Connection Point  \
# Label                                          ...
# 1.0                    2053              2053  ...              2053
# 2.0                    1388              1388  ...              1388
# 3.0                     947               947  ...               947
# 4.0                     226               226  ...               226
# 5.0                    2389              2389  ...              2389
# 6.0                    2291              2291  ...              2291
#
#        Total Load/Rate  Total Load/Latest  Unknown Load/Rate  \
# Label
# 1.0               2053               2053               2053
# 2.0               1388               1388               1388
# 3.0                947                947                947
# 4.0                226                226                226
# 5.0               2389               2389               2389
# 6.0               2291               2291               2291
#
#        Unknown Load/Latest  Latest bytes counter  Active Flow Entries  \
# Label
# 1.0                   2053                  2053                 2053
# 2.0                   1388                  1388                 1388
# 3.0                    947                   947                  947
# 4.0                    226                   226                  226
# 5.0                   2389                  2389                 2389
# 6.0                   2291                  2291                 2291
#
#        Packets Looked Up  Packets Matched  Label
# Label
# 1.0                 2053             2053   2053
# 2.0                 1388             1388   1388
# 3.0                  947              947    947
# 4.0                  226              226    226
# 5.0                 2389             2389   2389
# 6.0                 2291             2291   2291
#
# [6 rows x 22 columns]

# %%
#Random Forest as a classification algorithm
#make_pipeline to make shure train and test data are seperated do not influence each other
#pipeline to make shure train and test data are scaled
from sklearn.pipeline import make_pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier

rfc_model1 = make_pipeline(MinMaxScaler(), RandomForestClassifier(n_estimators=100, max_depth=100))
rfc_model1.fit(X_train.values, y_train)
# Out:
# Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=100))])

# %%
y_pred = rfc_model1.fit(X_train.values, y_train).predict(X_test.values)
y_true = y_test

# %%
#Show how many predictions are wrong 
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 9294 points : 486

# %%
#Accuracy Score of predicted values if it is normal or attack
from sklearn.metrics import balanced_accuracy_score, accuracy_score
print("Accuracy Score: " + str(accuracy_score(y_test, y_pred)))
print("Balanced Accuracy Score: " + str(balanced_accuracy_score(y_test, y_pred)))
# Out:
# Accuracy Score: 0.94770819883796
# Balanced Accuracy Score: 0.9222221074155991

# %%
#Confusion Matrix shows 

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)
cmd = ConfusionMatrixDisplay(cm, display_labels=["Blackhole", "Diversion", "Normal", "Overflow", "PortScan", "TCP-SYN"])
cmd.plot()

# %%
#Precision score measure the success of prediction when the classes are very imbalanced (Attack and normal are imbalanced)
from sklearn.metrics import precision_score
print("Precision Score: " +str(precision_score(y_true, y_pred, average="weighted", zero_division=0)))
# Out:
# Precision Score: 0.9487551004115752

# %%
#Recall is euqal to Accuracy Score
from sklearn.metrics import recall_score
print("Recall Score: " +str(recall_score(y_true, y_pred, average="weighted", zero_division=0)))
# Out:
# Recall Score: 0.94770819883796

# %%
#F1 Score interpreted as a harmonic mean of the precision and recall. Value between 0 (worst) and 1 (best)
print("F1 Score: " +str(f1_score(y_test, y_pred, average="weighted", zero_division=0)))
# Out:
# F1 Score: 0.9476521992261239
